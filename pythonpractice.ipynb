# %%
import pandas as pd

# %%
print ("this is sathvik ")
# Out:
# this is sathvik

# %%
# this is 26th december i will be working with respect to using the python in order to get back on track 

x = 12 

y = 23455

x + y  #(addition ,, subtraction , multiplication , division - base core fundamentals )
# Out:
# 23467

# %%
pip install ipython-sql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import configparser
# %load_ext sql  # this allows us to run

# %%
## 12th jan starting my journey with python basics once again  with commitment and discpline 

print ('i love macbooks "macbook pro"')
# Out:
# i love macbooks "macbook pro"

# %%
print ("i love macbooks \' i love macbooks \'")
# Out:
# i love macbooks ' i love macbooks '

# %%
#naming conventions are generally of three types 

my_Variable = 23 

my_variables = 43 

My_Variables = 56

print ( my_Variable)
print (my_variables)
print(My_Variables)
# Out:
# 23
# 43
# 56

# %%
def sum_positive(numbers):
    total = 0 # taking zero first 

    for num in numbers : 
        if num>0 :
            total = total + num 

    return total 


# Test it
print(sum_positive([1, -2, 3, -4, 5]))  # Should print 9
print(sum_positive([-1, -2, -3]))  # Should print 0
print(sum_positive([10, 20, 30]))
# Out:
# 9
# 0
# 60

# %%
def find_max(numbers):
    total = numbers[0] 
    for num in numbers: # so aggregation values are not supported in list and int so cant use > 
        if num > total:
            total = num
    return total

print(find_max([3, 7, 2, 9, 1]))  # Should print 9
print(find_max([-5, -2, -8]))     # Should print -2
print(find_max([100]))             # Should print 100
# Out:
# 9
# -2
# 100

# %%
def count_occurrences(numbers, target):
    total = 0 
    for num in numbers :
        if num == target:
            total = total+1
    return total # so the numbers get checked and if the numbers match then it adds +1 
    pass

print(count_occurrences([2,3,2,2,21,1,1,21,1,3,4,2],2))
# Out:
# 4

# %%
def filter_evens(numbers):
    result=[]
    for num in numbers:
        if num %2 == 0 : 
            result.append(num)
    return result
    pass

print(filter_evens([1, 2, 3, 4, 5, 6]))  # Should print [2, 4, 6]
print(filter_evens([1, 3, 5]))  # Should print []
print(filter_evens([10, 15, 20, 25]))  # Should print [10, 20]
# Out:
# [2, 4, 6]
# []
# [10, 20]

# %%
def filter_evens(numbers):
    result = []
    for num in numbers:
        if num % 2 == 0:
            result.append(num)
    print(result)  # Shows it on screen
    # No return → function gives back None

print(filter_evens([1, 2, 3, 4, 5, 6]))  # Should print [2, 4, 6]
# Out:
# [2, 4, 6]
# None

# %%
def calculate_average(numbers):
    results = 0
    for num in numbers:
        results = results + num
        average = results/len(numbers)
    return average
    pass

print(calculate_average([10, 20, 30]))  # Should print 20.0
print(calculate_average([5, 15]))  # Should print 10.0
print(calculate_average([100]))
# Out:
# 20.0
# 10.0
# 100.0

# %%
def find_min(numbers):
    smallest = numbers[0]
    for num in numbers:
        if num < smallest:
            smallest = num
    return smallest

print(find_min([5,3,5,1,5]))  # Should print 1
print(find_min([-5, -2, -8]))     # Should print -8
print(find_min([100]))             # Should print 100
# Out:
# 1
# -8
# 100

# %%
def first_and_last(items):
    first = items[0]
    last = items[-1]
    return [first,last]


print(first_and_last([1, 2, 3, 4, 5]))  # Should print [1, 5]
print(first_and_last(['a', 'b', 'c']))  # Should print ['a', 'c']
print(first_and_last([100]))            # Should print [100, 100]
# Out:
# [1, 5]
# ['a', 'c']
# [100, 100]

# %%
def reverse_list(items):
    reverse=[]
    reverse.append(items[::-1])
    return reverse
    

print(reverse_list([1, 2, 3, 4, 5]))  # Should print [5, 4, 3, 2, 1]
print(reverse_list(['a', 'b', 'c']))  # Should print ['c', 'b', 'a']
print(reverse_list([10]))
# Out:
# [[5, 4, 3, 2, 1]]
# [['c', 'b', 'a']]
# [[10]]

# %%
def remove_duplicates(items):
    duplicates = []
    for item in items:
        if item not in duplicates :
            duplicates.append(item)
    return duplicates

print(remove_duplicates([1, 2, 2, 3, 4, 4, 5]))  # Should print [1, 2, 3, 4, 5]
print(remove_duplicates(['a', 'b', 'a', 'c']))   # Should print ['a', 'b', 'c']
print(remove_duplicates([5, 5, 5]))              # Should print [5]
# Out:
# [1, 2, 3, 4, 5]
# ['a', 'b', 'c']
# [5]

# %%
# Example 1: Just checking (no adding)
results = [1, 2, 3]

print(5 not in results)  # Prints: True (5 is missing)
print(2 not in results)  # Prints: False (2 is there)
print(results)  # Still [1, 2, 3] - nothing added!

print("---")

# Example 2: Checking AND adding
results = [1, 2, 3]

if 5 not in results:
    results.append(5)
    print("Added 5")

if 2 not in results:
    results.append(2)
    print("This won't print")

print(results)  # Now [1, 2, 3, 5] - 5 was added!
# Out:
# True
# False
# [1, 2, 3]
# ---
# Added 5
# [1, 2, 3, 5]

# %%
def sum_of_squares(numbers):
    total = 0 
    for num in numbers: 
        total = total + (num*num)
    return total 
    pass

print(sum_of_squares([1, 2, 3]))  # Should print 14 (1² + 2² + 3² = 1 + 4 + 9)
print(sum_of_squares([2, 4]))     # Should print 20 (4 + 16)
print(sum_of_squares([5]))
# Out:
# 14
# 20
# 25

# %%
def count_pos_neg(numbers):
    pos_count = 0 
    neg_count = 0
    for num in numbers: 
        if num>0:
            pos_count = pos_count + 1 # i had the first understanding that i would be able to work this through with poscount+ 1 but i little did i know that i was right 
        if num<0:
            neg_count = neg_count + 1 
    return { "negative ":neg_count, "positive":pos_count}

    
    pass

print(count_pos_neg([1, -2, 3, -4, 5]))  
# Should print {'positive': 3, 'negative': 2}

print(count_pos_neg([-1, -2, -3]))      
# Should print {'positive': 0, 'negative': 3}

print(count_pos_neg([10, 20, 30]))       
# Should print {'positive': 3, 'negative': 0}
# Out:
# {'negative ': 2, 'positive': 3}
# {'negative ': 3, 'positive': 0}
# {'negative ': 0, 'positive': 3}

# %%
def even_positions(items):
    # my task is to find out even positions from the list 
    even_pos = []
    for i in range(len(items)): # i almost got this right 
        if i % 2 ==1 :
            even_pos.append(items[i])
    return even_pos
    pass

print(even_positions([10, 20, 30, 40, 50]))  
# Should print [10, 30, 50] (indexes 0, 2, 4)

print(even_positions(['a', 'b', 'c', 'd']))  
# Should print ['a', 'c'] (indexes 0, 2)

print(even_positions([1, 2]))                
# Should print [1] (index 0)
# Out:
# [20, 40]
# ['b', 'd']
# [2]

# %%
def even_position (items):
    even_pos = [items]


    return even_pos[1::2]


print (even_positions([10,20,20,30,40]))
# Out:
# [20, 30]

# %%
# this showcases that the position is even 

# basically in order for me to find out the sum its total / average 
# counting occurences total + 1

# %%
# ffunction that returns product of all numbers 

def multiply_all(numbers):
    product = 1 # the logic learnt here is i should be able to actively use out the specific numbers so multiplcation needs 1 , addtion and subtractiions needs 0 and given that the num gets counted , so i dont have to count all the numbers so if i say num* num only gives me 2 values rather saying product * num gives me whole understanding about whats exactly happening and that is product starts from 1 and starts multiping the entire numbers with 1 that way the entire list is being taken care of ? so the list multiplication helps take a better approach 
    for num in numbers : 
        product = product*num

    return product 
    pass

print(multiply_all([2, 3, 4]))     # Should print 24 (2 × 3 × 4)
print(multiply_all([5, 10]))       # Should print 50 (5 × 10)
print(multiply_all([1, 2, 3, 4]))  # Should print 24 (1 × 2 × 3 × 4)
# Out:
# 24
# 50
# 24

# %%
# i am writing a function that returns true if any thing related to the list actually comes out to be a duplicate and false if any thing turns out to be a unique value

def has_duplicates(items):
    counter = [] 
    for item in items: # here range cant be used in order to take that periodically and i would have to work around with a proper understanding of what that would looking like hence it was showing error , range , len is something i would have to look into 
        if item in counter: # my workaround for this specific question is it
            return True # so bascially this is just going through list and if anything comes up to be true then its not unique , false then its unique 
        counter.append(item)
    return False

print(has_duplicates([1, 2, 3, 4, 5]))  # Should print False (all unique)
print(has_duplicates([1, 2, 2, 3]))     # Should print True (2 appears twice)
print(has_duplicates(['a', 'b', 'a']))  # Should print True ('a' appears twice)
print(has_duplicates([10]))             # Should print False (only one item)
# Out:
# False
# True
# True
# False

# %%
def has_duplicates(items):
    counter = [] 
    for item in items : 
        if item in counter:
            return True  
        counter.append(item)
    return False 

print(has_duplicates([1,2,2,3,45,3,6]))
# Out:
# True

# %%
def second_largest(numbers):
    sec = numbers[0] 
    for num in numbers:
        if num>sec:
            sec = num
    return sec
    pass

print(second_largest([10, 5, 8, 12, 3]))  # Should print 10
print(second_largest([1, 2, 3, 4, 5]))    # Should print 4
print(second_largest([100, 200]))         # Should print 100

# %%
def fizzbuzz(n):
    for i in range(1,n+1):
        if i%15==0:
            print("Fizzbuzz")
        elif i%3 ==0:
            print("fizz")
        elif i%5 == 0 : 
            print("buzz")
        else:
            print(i)

if __name__ == "__main__":
    n = int(input().strip())
    fizzbuzz(n)

# %%
def second_largest(numbers):
    sorted_num = sorted(numbers)
    return sorted_num[-2]

print(second_largest([10, 5, 8, 12, 3]))  # Should print 10
print(second_largest([1, 2, 3, 4, 5]))    # Should print 4
print(second_largest([100, 200]))         # Should print 100
# Out:
# 10
# 4
# 100

# %%
def second_largest(numbers):
    largest = 0
    second = 0
    for num in numbers : 
        if num > largest:
            second = largest
            largest = num
        elif num > second and num != largest:
            second = num
    return second

print(second_largest([10, 5, 8, 12, 3]))  # Should print 10
print(second_largest([1, 2, 3, 4, 5]))    # Should print 4
print(second_largest([100, 200]))         # Should print 100
# Out:
# 10
# 4
# 100

# %%
def filter_greater_than_ten(numbers):
    largest = []
    for num in numbers:
        if num>10:
            largest.append(num) 
    return largest

print(filter_greater_than_ten([5, 12, 8, 15, 3, 20]))  # Should print [12, 15, 20]
print(filter_greater_than_ten([1, 2, 3]))              # Should print []
print(filter_greater_than_ten([15, 20, 25]))           # Should print [15, 20, 25]
# Out:
# [12, 15, 20]
# []
# [15, 20, 25]

# %%
#### string manipulation 
def count_words(text):
    in_word = False 
    count = 0 
    for word in text:
        if word != " ":
            if not in_word:
                count = count + 1 
                in_word = True 
        else : 
            in_word = False  
    return count  

    pass

print(count_words("hello world"))           # Should print 2
print(count_words("Python is awesome"))     # Should print 3
print(count_words("single"))                # Should print 1
# Out:
# 2
# 3
# 1

# %%
#### string manipulation 


def count_words(text):
    words = text.split() #splits each one of them into mutliple parts and then we do len( of the split string wooow gawddamn)
    return len(words)

    pass

print(count_words("hello world"))           # Should print 2
print(count_words("Python is awesome"))     # Should print 3
print(count_words("single"))                # Should print 1
# Out:
# 2
# 3
# 1

# %%
def check_even_odd(number):
        if number % 2 == 0 : 
            return "even"
        else:
            return "odd" 

print(check_even_odd(4))   # Should print "even"
print(check_even_odd(7))   # Should print "odd"
print(check_even_odd(10))  # Should print "even"
# Out:
# even
# odd
# even

# %%
def sum_evens(numbers):
    numo = 0
    for num in numbers:
        if num % 2 == 0 :
            numo = numo + num 
    return numo
    pass

print(sum_evens([1, 2, 3, 4, 5, 6]))  # Should print 12 (2+4+6)
print(sum_evens([1, 3, 5]))           # Should print 0
print(sum_evens([10, 20, 30]))        # Should print 60
# Out:
# 12
# 0
# 60

# %% [markdown]
# ### Confession to make i have been not able to code at all and i need to up my consistency scale which i will moving forward , task should be the focus nothing else and everything else is just noise

# %%
## string manipulation 

def longest_word(text):
    count = text.split()
    longest = ""
    for word in count:
        if len(word) > len(longest):
            longest = word 
    return longest 
    pass

print(longest_word("The quick brown fox"))     # Should print "quick" or "brown" (both length 5)
print(longest_word("Python is awesome"))       # Should print "awesome"
print(longest_word("I love coding"))           # Should print "coding"
# Out:
# quick
# awesome
# coding

# %%
def remove_vowels(text):
    vowel = ""
    for letter in text:
        if letter not in  "aeiou"  : 
            vowel = vowel+letter
    return vowel
    pass

print(remove_vowels("hello world"))    # Should print "hll wrld"
print(remove_vowels("Python"))         # Should print "Pythn"
print(remove_vowels("aeiou"))          # Should print ""
# Out:
# hll wrld
# Pythn

# %%
# its 16th march and i finally did it , took a break and got back up now heres the next question that needs to be solved 

def count_word_frequency(text):
        count = text.split()
        result = {}
        for word in count:
                if word in result:
                        result[word] = result[word] + 1
                else:
                        result[word] = 1
        return result
        

print(count_word_frequency("hello world hello"))
# Should print {'hello': 2, 'world': 1}

print(count_word_frequency("the cat and the dog"))
# Should print {'the': 2, 'cat': 1, 'and': 1, 'dog': 1}
# Out:
# {'hello': 2, 'world': 1}
# {'the': 2, 'cat': 1, 'and': 1, 'dog': 1}

# %%
word = {}
counts = ['plle','banana']

for count in counts:
    word[count] = word.get(count,0)+1

# %%
def reverse_words(text):
    count = text.split()
    reverse = []
    for word in count:
        reverse.append( word[::-1])
    return " ".join(reverse)
    pass

print(reverse_words("hello world"))      # Should print "olleh dlrow"
print(reverse_words("Python is fun"))    # Should print "nohtyP si nuf"
print(reverse_words("abc"))              # Should print "cba"
# Out:
# olleh dlrow
# nohtyP si nuf
# cba

# %%
def find_duplicates(numbers):
    # Step 1: Count how many times each number appears
    counts = {}
    for num in numbers:
        if num in counts:
            counts[num] = counts[num] + 1
        else:
            counts[num] = 1
    
    # Step 2: Find numbers that appear more than once
    duplicates = []
    for num, count in counts.items():
        if count > 1:
            duplicates.append(num)
    
    return duplicates

print(find_duplicates([1, 2, 3, 2, 4, 5, 1]))  # [1, 2]
print(find_duplicates([1, 2, 3, 4, 5]))        # []
print(find_duplicates([5, 5, 5, 1, 1]))        # [5, 1]
# Out:
# [1, 2]
# []
# [5, 1]

# %%
# well i really have a consistency issue where i keep showing up on odd days , but i feel better and back from my slumber ( i burnout and took a huge break ) its 22nd march and i have got another 2 questions to solve 

def flatten_list(nested_list):
    result = []
    for res in nested_list:
        result.extend(res)
    return result 
    pass

print(flatten_list([[1, 2], [3, 4], [5]]))      # Should print [1, 2, 3, 4, 5]
print(flatten_list([[10], [20, 30], [40]]))     # Should print [10, 20, 30, 40]
print(flatten_list([['a', 'b'], ['c']]))        # Should print ['a', 'b', 'c']
# Out:
# [1, 2, 3, 4, 5]
# [10, 20, 30, 40]
# ['a', 'b', 'c']

# %%
# trying out without extend method to see how this will happen 
def flatten_list(nested_list):
    result = []
    for res in nested_list:
        for item in res:
            result.append(item)
    return result
    pass

print(flatten_list([[1, 2], [3, 4], [5]]))      # Should print [1, 2, 3, 4, 5]
print(flatten_list([[10], [20, 30], [40]]))     # Should print [10, 20, 30, 40]
print(flatten_list([['a', 'b'], ['c']]))        # Should print ['a', 'b', 'c']
# Out:
# [1, 2, 3, 4, 5]
# [10, 20, 30, 40]
# ['a', 'b', 'c']

# %%
# this is last problem for this entire foundation base problem solving from claude lets see how that works. 
def merge_dicts(dict1, dict2):
    result = { }
    for values in dict1, dict2:
        for items in values:
            result.update(values)
    return result
    pass

print(merge_dicts({'a': 1, 'b': 2}, {'b': 3, 'c': 4}))
# Should print {'a': 1, 'b': 3, 'c': 4}

print(merge_dicts({'x': 10}, {'y': 20, 'z': 30}))
# Should print {'x': 10, 'y': 20, 'z': 30}
# Out:
# {'a': 1, 'b': 3, 'c': 4}
# {'x': 10, 'y': 20, 'z': 30}
